# %%
from vizdoom import *
import random
import time
import numpy as np
from matplotlib import pyplot as plt
import os
from gym import Env
from gym.spaces import Discrete, Box
import cv2
import torch
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common import env_checker
from stable_baselines3 import PPO
from stable_baselines3.common.evaluation import evaluate_policy
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-fa3a98a7ff7d> in <module>
#       5 from matplotlib import pyplot as plt
#       6 import os
# ----> 7 from gym import Env
#       8 from gym.spaces import Discrete, Box
#       9 import cv2
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\gym\__init__.py in <module>
#      11 )
#      12 from gym.spaces import Space
# ---> 13 from gym.envs import make, spec, register
#      14 from gym import logger
#      15 from gym import vector
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\gym\envs\__init__.py in <module>
#       8
#       9 # Hook to load plugins from entry points
# ---> 10 _load_env_plugins()
#      11
#      12
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\gym\envs\registration.py in load_env_plugins(entry_point)
#     274
#     275         with context:
# --> 276             fn = plugin.load()
#     277             try:
#     278                 fn()
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\metadata.py in load(self)
#      75         """
#      76         match = self.pattern.match(self.value)
# ---> 77         module = import_module(match.group('module'))
#      78         attrs = filter(None, (match.group('attr') or '').split('.'))
#      79         return functools.reduce(getattr, attrs, module)
#
# ~\AppData\Local\Programs\Python\Python39\lib\importlib\__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\ale_py\gym.py in <module>
#       3 from gym.envs.registration import register
#       4
# ----> 5 from ale_py.roms.utils import rom_name_to_id, rom_id_to_name
#       6
#       7
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\ale_py\roms\__init__.py in <module>
#      92
#      93
# ---> 94 _RESOLVED_ROMS = _resolve_roms()
#      95
#      96 # Update module
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\ale_py\roms\__init__.py in _resolve_roms()
#      44         try:
#      45             # Resolve supported / unsupported roms
# ---> 46             supported, unsupported = package.resolve()
#      47
#      48             # We'll now get the update delta. The reason for this is two fold:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\ale_py\roms\utils.py in resolve(self)
#      58         # Iterate over all ROMs in the specified package
#      59         for resource in filter(
# ---> 60             lambda file: file.suffix == ".bin", resources.files(self.package).iterdir()
#      61         ):
#      62             resolved = resource.resolve()
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\importlib_resources\_py3.py in files(package)
#     133     Get a Traversable resource from a package
#     134     """
# --> 135     return _common.from_package(_get_package(package))
#     136
#     137
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\importlib_resources\_common.py in from_package(package)
#      17     """
#      18     spec = package_spec(package)
# ---> 19     return from_traversable_resources(spec) or fallback_resources(spec)
#      20
#      21
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\importlib_resources\_common.py in fallback_resources(spec)
#      30
#      31 def fallback_resources(spec):
# ---> 32     package_directory = Path(spec.origin).parent
#      33     try:
#      34         archive_path = spec.loader.archive
#
# ~\AppData\Local\Programs\Python\Python39\lib\pathlib.py in __new__(cls, *args, **kwargs)
#    1069         if cls is Path:
#    1070             cls = WindowsPath if os.name == 'nt' else PosixPath
# -> 1071         self = cls._from_parts(args, init=False)
#    1072         if not self._flavour.is_supported:
#    1073             raise NotImplementedError("cannot instantiate %r on your system"
#
# ~\AppData\Local\Programs\Python\Python39\lib\pathlib.py in _from_parts(cls, args, init)
#     694         # right flavour.
#     695         self = object.__new__(cls)
# --> 696         drv, root, parts = self._parse_args(args)
#     697         self._drv = drv
#     698         self._root = root
#
# ~\AppData\Local\Programs\Python\Python39\lib\pathlib.py in _parse_args(cls, args)
#     678                 parts += a._parts
#     679             else:
# --> 680                 a = os.fspath(a)
#     681                 if isinstance(a, str):
#     682                     # Force-cast str subclasses to str (issue #21127)
#
# TypeError: expected str, bytes or os.PathLike object, not NoneType

# %%
game = DoomGame()
game.load_config('github/ViZDoom/scenarios/defend_the_center.cfg')
game.init()

# %%
actions = np.identity(3, dtype=np.uint8)
actions
# Out:
# array([[1, 0, 0],
#        [0, 1, 0],
#        [0, 0, 1]], dtype=uint8)

# %%
random.choice(actions)
# Out:
# array([1, 0, 0], dtype=uint8)

# %%
game.new_episode()

# %%
game.is_episode_finished()
# Out:
# False

# %%
game.make_action(random.choice(actions))
# Out:
# -1.0

# %%
game.make_action??
# second param is frame skip
# Out:
# Docstring:
# make_action(*args, **kwargs)
# Overloaded function.
#
# 1. make_action(self: vizdoom.vizdoom.DoomGame, arg0: object) -> float
#
# 2. make_action(self: vizdoom.vizdoom.DoomGame, arg0: object, arg1: int) -> float
# Type:      method

# %%
episodes = 10
for episode in range(episodes):
    # Create new episode or game
    game.new_episode()
    # Checking game is not finished
    while not game.is_episode_finished():
        state = game.get_state()
        img = state.screen_buffer # Current state game image
        info = state.game_variables
        reward = game.make_action(random.choice(actions))
        print('reward: ', reward)
        time.sleep(0.02)
    print('Result: ', game.get_total_reward())
    time.sleep(2)
# Out:
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  -1.0
# Result:  1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  -1.0
# Result:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  -1.0
# Result:  1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  -1.0
# Result:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  -1.0
# Result:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  -1.0
# Result:  1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  -1.0
# Result:  1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  -1.0
# Result:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  -1.0
# Result:  1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  1.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  0.0
# reward:  -1.0
# Result:  0.0

# %%
game.close()

# %% [markdown]
# # 1. Converting VizDoom to Gym Environment

# %%
Box(low=0, high=255, shape=(320, 240), dtype=np.uint8).sample()
# Out:
# array([[146, 156,  74, ..., 181,  87, 204],
#        [149, 179,  16, ...,  93, 116,  41],
#        [218,  38,  34, ...,  31, 255,  72],
#        ...,
#        [154,  44,  18, ...,  21,  10, 200],
#        [165, 169, 100, ...,  36, 211, 122],
#        [105,  82,  18, ...,  31,  82,  28]], dtype=uint8)

# %%
Discrete(3).sample()
# Out:
# 1

# %%
actions[Discrete(3).sample()]
# Out:
# array([0, 0, 1], dtype=uint8)

# %%
# Create VizDoom OpenAi Gym Environment
class VizDoomGym(Env):
    def __init__(self, render=False):
        super().__init__()
        self.game = DoomGame()
        self.game.load_config('github/ViZDoom/scenarios/defend_the_center.cfg')
        self.observation_space = Box(low=0, high=255, shape=(100, 160, 1), dtype=np.uint8)
        self.action_space = Discrete(3)
        if render:
            self.game.set_window_visible(True)
        else:
            self.game.set_window_visible(False)
        self.game.init()

    def step(self, action):
        actions = np.identity(3, dtype=np.uint8)
        reward = self.game.make_action(actions[action], 4)
        if self.game.get_state():
            state = self.game.get_state().screen_buffer
            state = self.grayscale(state)
            ammo = self.game.get_state().game_variables[0]
        else:
            state = np.zeros(self.observation_space.shape)
            ammo = 0
        
        info = {"ammo": ammo}
        
        done = self.game.is_episode_finished()

        return state, reward, done, info

    def render():
        pass
    def reset(self):
        self.game.new_episode()
        state = self.game.get_state().screen_buffer
        return self.grayscale(state)

    def grayscale(self, observation):
        gray = cv2.cvtColor(np.moveaxis(observation, 0, -1), cv2.COLOR_BGR2GRAY)
        resize = cv2.resize(gray, (160,100), interpolation=cv2.INTER_CUBIC)
        state = np.reshape(resize, (100,160,1))
        return state

    def close(self):
        self.game.close()

# %%
env =  VizDoomGym(True)

# %%
state = env.reset()

# %%
env.step(0)
# Out:
# (array([[[67, 67, 67, ..., 67, 67, 67],
#          [91, 91, 79, ..., 91, 79, 79],
#          [67, 67, 67, ..., 67, 67, 67],
#          ...,
#          [19, 19, 11, ..., 47, 47, 55],
#          [19, 27, 19, ..., 47, 47, 47],
#          [11, 19, 19, ..., 27, 19, 19]],
#
#         [[67, 67, 67, ..., 67, 67, 67],
#          [91, 91, 79, ..., 91, 79, 79],
#          [67, 67, 67, ..., 67, 67, 67],
#          ...,
#          [19, 19, 11, ..., 47, 47, 55],
#          [19, 27, 19, ..., 47, 47, 47],
#          [11, 19, 19, ..., 27, 19, 19]],
#
#         [[67, 67, 67, ..., 67, 67, 67],
#          [91, 91, 79, ..., 91, 79, 79],
#          [67, 67, 67, ..., 67, 67, 67],
#          ...,
#          [19, 19, 11, ..., 47, 47, 55],
#          [19, 27, 19, ..., 47, 47, 47],
#          [11, 19, 19, ..., 27, 19, 19]]], dtype=uint8),
#  -4.0,
#  False,
#  array([50.]))

# %%
env.observation_space.sample().shape
# Out:
# (3, 240, 320)

# %%
env.close()

# %%
state
# Out:
# array([[35, 39, 39, ..., 39, 39, 39],
#        [59, 67, 59, ..., 67, 67, 91],
#        [79, 79, 79, ..., 79, 91, 91],
#        ...,
#        [19, 19, 11, ..., 47, 47, 55],
#        [19, 27, 19, ..., 47, 47, 47],
#        [11, 19, 19, ..., 27, 19, 19]], dtype=uint8)

# %%
env = VizDoomGym(True)
env_checker.check_env(env)

# %% [markdown]
# # 2. View Game State

# %%
plt.imshow(state, cmap='gray')

# %% [markdown]
# # 3. Setup Callback

# %%
class TrainLogCallback(BaseCallback):
    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainLogCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path

    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok=True)

    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)

        return True

# %%
CHECKPOINT_DIR = './train/train_defend'
LOG_DIR = './logs/log_defend'

# %%
callback = TrainLogCallback(10000, CHECKPOINT_DIR)

# %% [markdown]
# # 4. Train Model

# %%
env = VizDoomGym()
model = PPO(
    'CnnPolicy', 
    env, 
    tensorboard_log=LOG_DIR, 
    verbose=1, 
    learning_rate=0.0001,
    n_steps=4096
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(total_timesteps=100000, callback=callback)
# Out:
# Logging to ./logs/log_defend\PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 79.7     |
# |    ep_rew_mean     | 0.157    |
# | time/              |          |
# |    fps             | 31       |
# |    iterations      | 1        |
# |    time_elapsed    | 129      |
# |    total_timesteps | 4096     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 84.4        |
# |    ep_rew_mean          | 0.396       |
# | time/                   |             |
# |    fps                  | 20          |
# |    iterations           | 2           |
# |    time_elapsed         | 394         |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.011609213 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.00659    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0353      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00793    |
# |    value_loss           | 0.132       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95.8        |
# |    ep_rew_mean          | 1.36        |
# | time/                   |             |
# |    fps                  | 18          |
# |    iterations           | 3           |
# |    time_elapsed         | 666         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012187562 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.454       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0178      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0194     |
# |    value_loss           | 0.117       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 103         |
# |    ep_rew_mean          | 2.12        |
# | time/                   |             |
# |    fps                  | 17          |
# |    iterations           | 4           |
# |    time_elapsed         | 944         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009752391 |
# |    clip_fraction        | 0.12        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.537       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0148      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0231     |
# |    value_loss           | 0.134       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 109         |
# |    ep_rew_mean          | 2.78        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 5           |
# |    time_elapsed         | 1210        |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.013147053 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.997      |
# |    explained_variance   | 0.626       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0115     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0299     |
# |    value_loss           | 0.122       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 117        |
# |    ep_rew_mean          | 3.43       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 6          |
# |    time_elapsed         | 1491       |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.01579678 |
# |    clip_fraction        | 0.162      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.977     |
# |    explained_variance   | 0.652      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0169    |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0358    |
# |    value_loss           | 0.15       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 127         |
# |    ep_rew_mean          | 4.2         |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 7           |
# |    time_elapsed         | 1734        |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.019169837 |
# |    clip_fraction        | 0.225       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.941      |
# |    explained_variance   | 0.716       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00779    |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0443     |
# |    value_loss           | 0.142       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 133         |
# |    ep_rew_mean          | 4.97        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 8           |
# |    time_elapsed         | 1980        |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.022431917 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.908      |
# |    explained_variance   | 0.703       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0504     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0443     |
# |    value_loss           | 0.162       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 137         |
# |    ep_rew_mean          | 5.55        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 9           |
# |    time_elapsed         | 2251        |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.020865336 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.854      |
# |    explained_variance   | 0.714       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0204     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0427     |
# |    value_loss           | 0.198       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 141         |
# |    ep_rew_mean          | 6.05        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 10          |
# |    time_elapsed         | 2529        |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.020662297 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.819      |
# |    explained_variance   | 0.8         |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00393    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.039      |
# |    value_loss           | 0.169       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 140         |
# |    ep_rew_mean          | 6.19        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 11          |
# |    time_elapsed         | 2792        |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.024540942 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.805      |
# |    explained_variance   | 0.849       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0431     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0469     |
# |    value_loss           | 0.16        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 149         |
# |    ep_rew_mean          | 6.89        |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 12          |
# |    time_elapsed         | 3072        |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.021879803 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.775      |
# |    explained_variance   | 0.86        |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.018      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0385     |
# |    value_loss           | 0.178       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 153        |
# |    ep_rew_mean          | 7.28       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 13         |
# |    time_elapsed         | 3306       |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.02250234 |
# |    clip_fraction        | 0.214      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.743     |
# |    explained_variance   | 0.871      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0234    |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0426    |
# |    value_loss           | 0.18       |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 162        |
# |    ep_rew_mean          | 7.97       |
# | time/                   |            |
# |    fps                  | 16         |
# |    iterations           | 14         |
# |    time_elapsed         | 3548       |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.02252039 |
# |    clip_fraction        | 0.211      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.712     |
# |    explained_variance   | 0.888      |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.0345    |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0394    |
# |    value_loss           | 0.183      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 171         |
# |    ep_rew_mean          | 8.64        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 15          |
# |    time_elapsed         | 3779        |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.024557909 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.697      |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00925    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0442     |
# |    value_loss           | 0.155       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 178         |
# |    ep_rew_mean          | 9.37        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 16          |
# |    time_elapsed         | 4022        |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.025591731 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.661      |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0211     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0396     |
# |    value_loss           | 0.175       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 184         |
# |    ep_rew_mean          | 9.87        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 17          |
# |    time_elapsed         | 4290        |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.023900844 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.597      |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0259     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0344     |
# |    value_loss           | 0.137       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 193         |
# |    ep_rew_mean          | 10.6        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 18          |
# |    time_elapsed         | 4562        |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.027832754 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.608      |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0437     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0397     |
# |    value_loss           | 0.155       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 201         |
# |    ep_rew_mean          | 11.3        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 19          |
# |    time_elapsed         | 4828        |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.026126307 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.575      |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0175     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0378     |
# |    value_loss           | 0.111       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 207         |
# |    ep_rew_mean          | 11.9        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 20          |
# |    time_elapsed         | 5097        |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.025464084 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.532      |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0267     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0377     |
# |    value_loss           | 0.124       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 212         |
# |    ep_rew_mean          | 12.3        |
# | time/                   |             |
# |    fps                  | 16          |
# |    iterations           | 21          |
# |    time_elapsed         | 5370        |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.023863109 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.523      |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0348     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0372     |
# |    value_loss           | 0.128       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 215         |
# |    ep_rew_mean          | 12.7        |
# | time/                   |             |
# |    fps                  | 15          |
# |    iterations           | 22          |
# |    time_elapsed         | 5636        |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.025882188 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.52       |
# |    explained_variance   | 0.958       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0292     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.036      |
# |    value_loss           | 0.108       |
# -----------------------------------------

# %% [markdown]
# # 5. Test Model

# %%
## Continued at 1:46:05 while training
model = PPO.load('./train/train_basic/best_model_110000') ## Pass in model dir

# %%
env = VizDoomGym(render = True)

# %%
mean_reward, _ = evaluate_policy(model, env, n_eval_episodes=10)

# %%
mean_reward
# Out:
# 85.8

# %%
for episode in range(5):
    obs = env.reset()
    done = False
    total_reward = 0
    while not done:
        action, _ = model.predict(obs)
        obs, reward, done, info = env.step(action)
        time.sleep(0.25)
        total_reward += reward
    print('Total reward for episode {} is {}'.format(total_reward, episode))
    time.sleep(2)
# Out:
# Total reward for episode 95.0 is 0
# Total reward for episode 67.0 is 1
# Total reward for episode 83.0 is 2
# Total reward for episode 79.0 is 3
# Total reward for episode 95.0 is 4

# %%
env.close()
